# %%
from model_utils import bessel_rbf
import torch
import math
import matplotlib.pyplot as plt

# %%
xs = torch.arange(0.01,1.51,0.01).view(1,150)

# %%
bessel_rbf(xs, n=5, r_cut=1.6)[1].size()
# Out:
# torch.Size([150])

# %%
for row in bessel_rbf(xs, n=10, r_cut=2):
    plt.plot(range(len(row.tolist())), row.numpy())
plt.show()
